# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime
import requests
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 765

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description
                          })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
print(f"{len(city_data)} city records were retrived")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | san patricio
# Processing Record 2 of Set 1 | broome
# Processing Record 3 of Set 1 | hella
# Processing Record 4 of Set 1 | ponta do sol
# Processing Record 5 of Set 1 | talnakh
# Processing Record 6 of Set 1 | hithadhoo
# Processing Record 7 of Set 1 | beringovskiy
# Processing Record 8 of Set 1 | buloh kasap
# Processing Record 9 of Set 1 | hirara
# Processing Record 10 of Set 1 | bubaque
# Processing Record 11 of Set 1 | tuktoyaktuk
# Processing Record 12 of Set 1 | butaritari
# Processing Record 13 of Set 1 | karakendzha
# City not found. Skipping...
# Processing Record 14 of Set 1 | bluff
# Processing Record 15 of Set 1 | kapaa
# Processing Record 16 of Set 1 | bolungarvik
# City not found. Skipping...
# Processing Record 17 of Set 1 | cidreira
# Processing Record 18 of Set 1 | provideniya
# Processing Record 19 of Set 1 | qaanaaq
# Processing Record 20 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 21 of Set 1 | rikitea
# Processing Record 22 of Set 1 | hobart
# Processing Record 23 of Set 1 | baculin
# Processing Record 24 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 25 of Set 1 | touros
# Processing Record 26 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 27 of Set 1 | luderitz
# Processing Record 28 of Set 1 | khatanga
# Processing Record 29 of Set 1 | tuatapere
# Processing Record 30 of Set 1 | cuaspud
# Processing Record 31 of Set 1 | punta arenas
# Processing Record 32 of Set 1 | thompson
# Processing Record 33 of Set 1 | castro
# Processing Record 34 of Set 1 | isangel
# Processing Record 35 of Set 1 | vaini
# Processing Record 36 of Set 1 | jamestown
# Processing Record 37 of Set 1 | kaitangata
# Processing Record 38 of Set 1 | albany
# Processing Record 39 of Set 1 | toliary
# City not found. Skipping...
# Processing Record 40 of Set 1 | constitucion
# Processing Record 41 of Set 1 | hilo
# Processing Record 42 of Set 1 | galesong
# Processing Record 43 of Set 1 | deputatskiy
# Processing Record 44 of Set 1 | bredasdorp
# Processing Record 45 of Set 1 | baykit
# Processing Record 46 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 47 of Set 1 | krasnoselkup
# Processing Record 48 of Set 1 | bac giang
# Processing Record 49 of Set 1 | vila franca do campo
# Processing Record 50 of Set 1 | gharb
# City not found. Skipping...
# Processing Record 1 of Set 2 | woodstock
# Processing Record 2 of Set 2 | caohai
# Processing Record 3 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 4 of Set 2 | micheweni
# Processing Record 5 of Set 2 | cabedelo
# Processing Record 6 of Set 2 | hirschaid
# Processing Record 7 of Set 2 | samarai
# Processing Record 8 of Set 2 | port alfred
# Processing Record 9 of Set 2 | kegayli
# City not found. Skipping...
# Processing Record 10 of Set 2 | avarua
# Processing Record 11 of Set 2 | coquimbo
# Processing Record 12 of Set 2 | esil
# Processing Record 13 of Set 2 | longyearbyen
# Processing Record 14 of Set 2 | muros
# Processing Record 15 of Set 2 | ushuaia
# Processing Record 16 of Set 2 | kieta
# Processing Record 17 of Set 2 | kenora
# Processing Record 18 of Set 2 | kizukuri
# Processing Record 19 of Set 2 | buraydah
# Processing Record 20 of Set 2 | busselton
# Processing Record 21 of Set 2 | atuona
# Processing Record 22 of Set 2 | goderich
# Processing Record 23 of Set 2 | garmsar
# Processing Record 24 of Set 2 | bogotol
# Processing Record 25 of Set 2 | puerto ayora
# Processing Record 26 of Set 2 | hermanus
# Processing Record 27 of Set 2 | mataura
# Processing Record 28 of Set 2 | chokurdakh
# Processing Record 29 of Set 2 | tasiilaq
# Processing Record 30 of Set 2 | khandyga
# Processing Record 31 of Set 2 | kisangani
# Processing Record 32 of Set 2 | dikson
# Processing Record 33 of Set 2 | padang
# Processing Record 34 of Set 2 | pevek
# Processing Record 35 of Set 2 | forecariah
# Processing Record 36 of Set 2 | hun
# Processing Record 37 of Set 2 | fortuna
# Processing Record 38 of Set 2 | san quintin
# Processing Record 39 of Set 2 | toora-khem
# Processing Record 40 of Set 2 | lompoc
# Processing Record 41 of Set 2 | barrow
# Processing Record 42 of Set 2 | bargarh
# Processing Record 43 of Set 2 | green valley
# Processing Record 44 of Set 2 | victoria
# Processing Record 45 of Set 2 | acapulco
# Processing Record 46 of Set 2 | pisco
# Processing Record 47 of Set 2 | auki
# Processing Record 48 of Set 2 | katsuura
# Processing Record 49 of Set 2 | san-pedro
# Processing Record 50 of Set 2 | kodiak
# Processing Record 1 of Set 3 | mullaitivu
# City not found. Skipping...
# Processing Record 2 of Set 3 | kahului
# Processing Record 3 of Set 3 | prattville
# Processing Record 4 of Set 3 | clyde river
# Processing Record 5 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 6 of Set 3 | lebowakgomo
# Processing Record 7 of Set 3 | new norfolk
# Processing Record 8 of Set 3 | princeton
# Processing Record 9 of Set 3 | geraldton
# Processing Record 10 of Set 3 | bealanana
# Processing Record 11 of Set 3 | kruisfontein
# Processing Record 12 of Set 3 | boyolangu
# Processing Record 13 of Set 3 | paamiut
# Processing Record 14 of Set 3 | ndele
# Processing Record 15 of Set 3 | bilyayivka
# Processing Record 16 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 17 of Set 3 | rassvet
# Processing Record 18 of Set 3 | arraial do cabo
# Processing Record 19 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 20 of Set 3 | mitsamiouli
# Processing Record 21 of Set 3 | ponta delgada
# Processing Record 22 of Set 3 | laja
# Processing Record 23 of Set 3 | aleksandrov gay
# Processing Record 24 of Set 3 | ossora
# Processing Record 25 of Set 3 | yellowknife
# Processing Record 26 of Set 3 | store heddinge
# Processing Record 27 of Set 3 | east london
# Processing Record 28 of Set 3 | harboore
# Processing Record 29 of Set 3 | rawson
# Processing Record 30 of Set 3 | yanahuanca
# Processing Record 31 of Set 3 | port elizabeth
# Processing Record 32 of Set 3 | norman wells
# Processing Record 33 of Set 3 | copperas cove
# Processing Record 34 of Set 3 | margate
# Processing Record 35 of Set 3 | mahadday weyne
# City not found. Skipping...
# Processing Record 36 of Set 3 | tasbuget
# City not found. Skipping...
# Processing Record 37 of Set 3 | narsaq
# Processing Record 38 of Set 3 | souillac
# Processing Record 39 of Set 3 | mar del plata
# Processing Record 40 of Set 3 | kolondieba
# Processing Record 41 of Set 3 | camocim
# Processing Record 42 of Set 3 | torbay
# Processing Record 43 of Set 3 | jiuquan
# Processing Record 44 of Set 3 | tiksi
# Processing Record 45 of Set 3 | tonstad
# Processing Record 46 of Set 3 | icanti
# City not found. Skipping...
# Processing Record 47 of Set 3 | cherskiy
# Processing Record 48 of Set 3 | praya
# Processing Record 49 of Set 3 | huarmey
# Processing Record 50 of Set 3 | carutapera
# Processing Record 1 of Set 4 | tazmalt
# Processing Record 2 of Set 4 | mykolayivka
# Processing Record 3 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 4 of Set 4 | leningradskiy
# Processing Record 5 of Set 4 | bur gabo
# City not found. Skipping...
# Processing Record 6 of Set 4 | bradut
# Processing Record 7 of Set 4 | ganzhou
# Processing Record 8 of Set 4 | jutai
# Processing Record 9 of Set 4 | beloha
# Processing Record 10 of Set 4 | ilulissat
# Processing Record 11 of Set 4 | alofi
# Processing Record 12 of Set 4 | laiyang
# Processing Record 13 of Set 4 | flin flon
# Processing Record 14 of Set 4 | vostok
# Processing Record 15 of Set 4 | malibu
# Processing Record 16 of Set 4 | georgetown
# Processing Record 17 of Set 4 | dunedin
# Processing Record 18 of Set 4 | inderborskiy
# City not found. Skipping...
# Processing Record 19 of Set 4 | novomikhaylovskiy
# Processing Record 20 of Set 4 | basco
# Processing Record 21 of Set 4 | balikpapan
# Processing Record 22 of Set 4 | chapais
# Processing Record 23 of Set 4 | bhanpura
# Processing Record 24 of Set 4 | claudio
# Processing Record 25 of Set 4 | ondorhaan
# City not found. Skipping...
# Processing Record 26 of Set 4 | te anau
# Processing Record 27 of Set 4 | wulanhaote
# City not found. Skipping...
# Processing Record 28 of Set 4 | gornozavodsk
# Processing Record 29 of Set 4 | balabac
# Processing Record 30 of Set 4 | solesti
# Processing Record 31 of Set 4 | codrington
# Processing Record 32 of Set 4 | sechura
# Processing Record 33 of Set 4 | jhang
# Processing Record 34 of Set 4 | bambous virieux
# Processing Record 35 of Set 4 | lorengau
# Processing Record 36 of Set 4 | khomeynishahr
# City not found. Skipping...
# Processing Record 37 of Set 4 | phonhong
# Processing Record 38 of Set 4 | mecca
# Processing Record 39 of Set 4 | meshchovsk
# Processing Record 40 of Set 4 | waingapu
# Processing Record 41 of Set 4 | saint-philippe
# Processing Record 42 of Set 4 | dwarka
# Processing Record 43 of Set 4 | klyuchi
# Processing Record 44 of Set 4 | sao felix do xingu
# Processing Record 45 of Set 4 | lebu
# Processing Record 46 of Set 4 | kalyazin
# Processing Record 47 of Set 4 | hasaki
# Processing Record 48 of Set 4 | raga
# Processing Record 49 of Set 4 | bowen
# Processing Record 50 of Set 4 | valparaiso
# Processing Record 1 of Set 5 | vila velha
# Processing Record 2 of Set 5 | andenes
# Processing Record 3 of Set 5 | cape town
# Processing Record 4 of Set 5 | tshikapa
# Processing Record 5 of Set 5 | chernyshevskiy
# Processing Record 6 of Set 5 | airai
# Processing Record 7 of Set 5 | grindavik
# Processing Record 8 of Set 5 | santa isabel do rio negro
# Processing Record 9 of Set 5 | upington
# Processing Record 10 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 11 of Set 5 | acarau
# Processing Record 12 of Set 5 | avera
# Processing Record 13 of Set 5 | kavaratti
# Processing Record 14 of Set 5 | ribeira grande
# Processing Record 15 of Set 5 | rio gallegos
# Processing Record 16 of Set 5 | nanzhang
# Processing Record 17 of Set 5 | rongcheng
# Processing Record 18 of Set 5 | kalispell
# Processing Record 19 of Set 5 | kaeo
# Processing Record 20 of Set 5 | palu
# Processing Record 21 of Set 5 | ahipara
# Processing Record 22 of Set 5 | husavik
# Processing Record 23 of Set 5 | shimoda
# Processing Record 24 of Set 5 | beidao
# Processing Record 25 of Set 5 | matam
# Processing Record 26 of Set 5 | muisne
# Processing Record 27 of Set 5 | matagami
# Processing Record 28 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 29 of Set 5 | unye
# City not found. Skipping...
# Processing Record 30 of Set 5 | mbandaka
# Processing Record 31 of Set 5 | artyk
# City not found. Skipping...
# Processing Record 32 of Set 5 | chicama
# Processing Record 33 of Set 5 | tual
# Processing Record 34 of Set 5 | rocha
# Processing Record 35 of Set 5 | cockburn town
# Processing Record 36 of Set 5 | wucheng
# Processing Record 37 of Set 5 | guaruja
# Processing Record 38 of Set 5 | matveyevka
# Processing Record 39 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 40 of Set 5 | pravokumskoye
# Processing Record 41 of Set 5 | sahuaripa
# Processing Record 42 of Set 5 | finschhafen
# Processing Record 43 of Set 5 | bahraich
# Processing Record 44 of Set 5 | southbridge
# Processing Record 45 of Set 5 | tura
# Processing Record 46 of Set 5 | sioux lookout
# Processing Record 47 of Set 5 | destin
# Processing Record 48 of Set 5 | konya
# Processing Record 49 of Set 5 | guerrero negro
# Processing Record 50 of Set 5 | shieli
# Processing Record 1 of Set 6 | shahe
# Processing Record 2 of Set 6 | tucurui
# Processing Record 3 of Set 6 | half moon bay
# Processing Record 4 of Set 6 | prince albert
# Processing Record 5 of Set 6 | mahebourg
# Processing Record 6 of Set 6 | phibun mangsahan
# Processing Record 7 of Set 6 | port hardy
# Processing Record 8 of Set 6 | lavrentiya
# Processing Record 9 of Set 6 | gat
# Processing Record 10 of Set 6 | carnarvon
# Processing Record 11 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 12 of Set 6 | caucaia
# Processing Record 13 of Set 6 | gordeyevka
# Processing Record 14 of Set 6 | sibu
# Processing Record 15 of Set 6 | yelizovo
# Processing Record 16 of Set 6 | naze
# Processing Record 17 of Set 6 | saint anthony
# Processing Record 18 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 19 of Set 6 | batemans bay
# Processing Record 20 of Set 6 | haibowan
# City not found. Skipping...
# Processing Record 21 of Set 6 | bugojno
# Processing Record 22 of Set 6 | old road
# City not found. Skipping...
# Processing Record 23 of Set 6 | ulaangom
# Processing Record 24 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 25 of Set 6 | sur
# Processing Record 26 of Set 6 | yar-sale
# Processing Record 27 of Set 6 | abu samrah
# Processing Record 28 of Set 6 | nanortalik
# Processing Record 29 of Set 6 | batagay
# Processing Record 30 of Set 6 | rome
# Processing Record 31 of Set 6 | show low
# Processing Record 32 of Set 6 | buchanan
# Processing Record 33 of Set 6 | baghdad
# Processing Record 34 of Set 6 | anloga
# Processing Record 35 of Set 6 | nuuk
# Processing Record 36 of Set 6 | anadyr
# Processing Record 37 of Set 6 | lulea
# Processing Record 38 of Set 6 | san cristobal
# Processing Record 39 of Set 6 | bathsheba
# Processing Record 40 of Set 6 | saint-pierre
# Processing Record 41 of Set 6 | alyangula
# Processing Record 42 of Set 6 | iqaluit
# Processing Record 43 of Set 6 | isilkul
# Processing Record 44 of Set 6 | paragominas
# Processing Record 45 of Set 6 | kagoro
# Processing Record 46 of Set 6 | phalodi
# Processing Record 47 of Set 6 | mayo
# Processing Record 48 of Set 6 | tabou
# Processing Record 49 of Set 6 | poshekhonye
# Processing Record 50 of Set 6 | pacific grove
# Processing Record 1 of Set 7 | tarauaca
# Processing Record 2 of Set 7 | ostrovnoy
# Processing Record 3 of Set 7 | vardo
# Processing Record 4 of Set 7 | vakhrushev
# Processing Record 5 of Set 7 | banda aceh
# Processing Record 6 of Set 7 | khonuu
# City not found. Skipping...
# Processing Record 7 of Set 7 | berlevag
# Processing Record 8 of Set 7 | mount gambier
# Processing Record 9 of Set 7 | port lincoln
# Processing Record 10 of Set 7 | algiers
# Processing Record 11 of Set 7 | saint george
# Processing Record 12 of Set 7 | hambantota
# Processing Record 13 of Set 7 | esperance
# Processing Record 14 of Set 7 | vanderhoof
# Processing Record 15 of Set 7 | ratnagiri
# Processing Record 16 of Set 7 | axim
# Processing Record 17 of Set 7 | burica
# City not found. Skipping...
# Processing Record 18 of Set 7 | caravelas
# Processing Record 19 of Set 7 | elmira
# Processing Record 20 of Set 7 | asau
# Processing Record 21 of Set 7 | hobyo
# Processing Record 22 of Set 7 | faanui
# Processing Record 23 of Set 7 | malakal
# Processing Record 24 of Set 7 | ancud
# Processing Record 25 of Set 7 | mandalgovi
# Processing Record 26 of Set 7 | puerto del rosario
# Processing Record 27 of Set 7 | saldanha
# Processing Record 28 of Set 7 | kalmunai
# Processing Record 29 of Set 7 | kondagaon
# Processing Record 30 of Set 7 | nsanje
# Processing Record 31 of Set 7 | kalia
# Processing Record 32 of Set 7 | kiunga
# Processing Record 33 of Set 7 | alta floresta
# Processing Record 34 of Set 7 | bereda
# Processing Record 35 of Set 7 | the pas
# Processing Record 36 of Set 7 | peniche
# Processing Record 37 of Set 7 | voi
# Processing Record 38 of Set 7 | upernavik
# Processing Record 39 of Set 7 | raudeberg
# Processing Record 40 of Set 7 | saskylakh
# Processing Record 41 of Set 7 | kulhudhuffushi
# Processing Record 42 of Set 7 | puquio
# Processing Record 43 of Set 7 | gayny
# Processing Record 44 of Set 7 | porbandar
# Processing Record 45 of Set 7 | amapa
# Processing Record 46 of Set 7 | nizhniy tsasuchey
# Processing Record 47 of Set 7 | labutta
# City not found. Skipping...
# Processing Record 48 of Set 7 | severo-kurilsk
# Processing Record 49 of Set 7 | dax
# Processing Record 50 of Set 7 | mangaratiba
# Processing Record 1 of Set 8 | jumla
# Processing Record 2 of Set 8 | bengkulu
# Processing Record 3 of Set 8 | barcelos
# Processing Record 4 of Set 8 | izyaslav
# Processing Record 5 of Set 8 | namibe
# Processing Record 6 of Set 8 | hovd
# Processing Record 7 of Set 8 | rolim de moura
# City not found. Skipping...
# Processing Record 8 of Set 8 | camp verde
# Processing Record 9 of Set 8 | bantogon
# Processing Record 10 of Set 8 | beruwala
# Processing Record 11 of Set 8 | cabo san lucas
# Processing Record 12 of Set 8 | bima
# Processing Record 13 of Set 8 | barbar
# City not found. Skipping...
# Processing Record 14 of Set 8 | mount isa
# Processing Record 15 of Set 8 | bilibino
# Processing Record 16 of Set 8 | anuradhapura
# Processing Record 17 of Set 8 | makurdi
# Processing Record 18 of Set 8 | sao gabriel da cachoeira
# Processing Record 19 of Set 8 | dudinka
# Processing Record 20 of Set 8 | ilmajoki
# Processing Record 21 of Set 8 | pangody
# Processing Record 22 of Set 8 | nouadhibou
# Processing Record 23 of Set 8 | trincomalee
# Processing Record 24 of Set 8 | cloquet
# Processing Record 25 of Set 8 | sitka
# Processing Record 26 of Set 8 | constantine
# Processing Record 27 of Set 8 | gandai
# Processing Record 28 of Set 8 | kikwit
# Processing Record 29 of Set 8 | olafsvik
# Processing Record 30 of Set 8 | pangnirtung
# Processing Record 31 of Set 8 | mehamn
# Processing Record 32 of Set 8 | laguna
# Processing Record 33 of Set 8 | yumen
# Processing Record 34 of Set 8 | kilindoni
# Processing Record 35 of Set 8 | bhawanipatna
# Processing Record 36 of Set 8 | lagoa
# Processing Record 37 of Set 8 | sofiysk
# City not found. Skipping...
# Processing Record 38 of Set 8 | lakes entrance
# Processing Record 39 of Set 8 | mufulira
# Processing Record 40 of Set 8 | sao filipe
# Processing Record 41 of Set 8 | itagiba
# Processing Record 42 of Set 8 | barroualie
# City not found. Skipping...
# Processing Record 43 of Set 8 | dedovichi
# Processing Record 44 of Set 8 | praia da vitoria
# Processing Record 45 of Set 8 | richards bay
# Processing Record 46 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 47 of Set 8 | mazyr
# Processing Record 48 of Set 8 | jieshi
# Processing Record 49 of Set 8 | ijaki
# City not found. Skipping...
# Processing Record 50 of Set 8 | bud
# Processing Record 1 of Set 9 | ust-nera
# Processing Record 2 of Set 9 | henties bay
# Processing Record 3 of Set 9 | virginia beach
# Processing Record 4 of Set 9 | salalah
# Processing Record 5 of Set 9 | lexington park
# Processing Record 6 of Set 9 | nabire
# Processing Record 7 of Set 9 | okha
# Processing Record 8 of Set 9 | prince rupert
# Processing Record 9 of Set 9 | wanning
# Processing Record 10 of Set 9 | viedma
# Processing Record 11 of Set 9 | kazalinsk
# City not found. Skipping...
# Processing Record 12 of Set 9 | sawtell
# Processing Record 13 of Set 9 | pilar
# Processing Record 14 of Set 9 | bocaranga
# City not found. Skipping...
# Processing Record 15 of Set 9 | weyburn
# Processing Record 16 of Set 9 | huilong
# Processing Record 17 of Set 9 | massakory
# Processing Record 18 of Set 9 | phalaborwa
# Processing Record 19 of Set 9 | juan lacaze
# Processing Record 20 of Set 9 | waddan
# Processing Record 21 of Set 9 | alto araguaia
# Processing Record 22 of Set 9 | klaksvik
# Processing Record 23 of Set 9 | lubao
# Processing Record 24 of Set 9 | bay roberts
# Processing Record 25 of Set 9 | khorixas
# Processing Record 26 of Set 9 | ocampo
# Processing Record 27 of Set 9 | bethlehem
# Processing Record 28 of Set 9 | darhan
# Processing Record 29 of Set 9 | hofn
# Processing Record 30 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 31 of Set 9 | diffa
# Processing Record 32 of Set 9 | san rafael
# Processing Record 33 of Set 9 | boshnyakovo
# Processing Record 34 of Set 9 | ngunguru
# Processing Record 35 of Set 9 | neuquen
# Processing Record 36 of Set 9 | riyadh
# Processing Record 37 of Set 9 | havelock
# Processing Record 38 of Set 9 | ardistan
# City not found. Skipping...
# Processing Record 39 of Set 9 | takoradi
# Processing Record 40 of Set 9 | santa isabel
# Processing Record 41 of Set 9 | seminole
# Processing Record 42 of Set 9 | labuhan
# Processing Record 43 of Set 9 | karakol
# Processing Record 44 of Set 9 | haines junction
# Processing Record 45 of Set 9 | nemuro
# Processing Record 46 of Set 9 | alexandria
# Processing Record 47 of Set 9 | bethel
# Processing Record 48 of Set 9 | nikolskoye
# Processing Record 49 of Set 9 | alotau
# City not found. Skipping...
# Processing Record 50 of Set 9 | nizhneudinsk
# Processing Record 1 of Set 10 | faya
# Processing Record 2 of Set 10 | jalu
# Processing Record 3 of Set 10 | west wendover
# Processing Record 4 of Set 10 | dongkan
# Processing Record 5 of Set 10 | samana
# Processing Record 6 of Set 10 | belmonte
# Processing Record 7 of Set 10 | bestobe
# Processing Record 8 of Set 10 | quatre cocos
# Processing Record 9 of Set 10 | escanaba
# Processing Record 10 of Set 10 | mahibadhoo
# Processing Record 11 of Set 10 | banhigan
# Processing Record 12 of Set 10 | zalantun
# Processing Record 13 of Set 10 | bitlis
# Processing Record 14 of Set 10 | talcahuano
# Processing Record 15 of Set 10 | coihueco
# Processing Record 16 of Set 10 | comodoro rivadavia
# Processing Record 17 of Set 10 | mandera
# Processing Record 18 of Set 10 | give
# Processing Record 19 of Set 10 | flinders
# Processing Record 20 of Set 10 | kawalu
# Processing Record 21 of Set 10 | hearst
# Processing Record 22 of Set 10 | alberton
# Processing Record 23 of Set 10 | namatanai
# Processing Record 24 of Set 10 | baza
# Processing Record 25 of Set 10 | fort nelson
# Processing Record 26 of Set 10 | sorata
# Processing Record 27 of Set 10 | darnetal
# Processing Record 28 of Set 10 | sumenep
# Processing Record 29 of Set 10 | rafai
# Processing Record 30 of Set 10 | lawton
# Processing Record 31 of Set 10 | valdivia
# Processing Record 32 of Set 10 | fairbanks
# Processing Record 33 of Set 10 | kurayoshi
# Processing Record 34 of Set 10 | saint-joseph
# Processing Record 35 of Set 10 | coahuayana
# Processing Record 36 of Set 10 | mochudi
# Processing Record 37 of Set 10 | wairoa
# Processing Record 38 of Set 10 | nome
# Processing Record 39 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 40 of Set 10 | porto velho
# Processing Record 41 of Set 10 | iberia
# Processing Record 42 of Set 10 | ambulu
# Processing Record 43 of Set 10 | yulara
# Processing Record 44 of Set 10 | muravlenko
# Processing Record 45 of Set 10 | bilma
# Processing Record 46 of Set 10 | tevaitoa
# Processing Record 47 of Set 10 | palaikastron
# Processing Record 48 of Set 10 | burgeo
# Processing Record 49 of Set 10 | tupik
# Processing Record 50 of Set 10 | peterhead
# Processing Record 1 of Set 11 | los lunas
# Processing Record 2 of Set 11 | maceio
# Processing Record 3 of Set 11 | temyasovo
# Processing Record 4 of Set 11 | dondo
# Processing Record 5 of Set 11 | hvide sande
# Processing Record 6 of Set 11 | gwadar
# Processing Record 7 of Set 11 | sorgun
# Processing Record 8 of Set 11 | moses lake
# Processing Record 9 of Set 11 | camacha
# Processing Record 10 of Set 11 | zaozerne
# Processing Record 11 of Set 11 | gravdal
# Processing Record 12 of Set 11 | yerbogachen
# Processing Record 13 of Set 11 | veraval
# Processing Record 14 of Set 11 | kintampo
# Processing Record 15 of Set 11 | makuyuni
# Processing Record 16 of Set 11 | opuwo
# Processing Record 17 of Set 11 | rosarito
# Processing Record 18 of Set 11 | kavieng
# Processing Record 19 of Set 11 | pitimbu
# Processing Record 20 of Set 11 | aden
# Processing Record 21 of Set 11 | midland
# Processing Record 22 of Set 11 | kachkanar
# Processing Record 23 of Set 11 | cuamba
# Processing Record 24 of Set 11 | abha
# Processing Record 25 of Set 11 | marsassoum
# Processing Record 26 of Set 11 | chateaubelair
# Processing Record 27 of Set 11 | ranavav
# Processing Record 28 of Set 11 | oyem
# Processing Record 29 of Set 11 | la ronge
# Processing Record 30 of Set 11 | la orilla
# Processing Record 31 of Set 11 | seoul
# Processing Record 32 of Set 11 | pozhva
# Processing Record 33 of Set 11 | domoni
# Processing Record 34 of Set 11 | kindu
# Processing Record 35 of Set 11 | quelimane
# Processing Record 36 of Set 11 | mala tokmachka
# Processing Record 37 of Set 11 | lobva
# Processing Record 38 of Set 11 | guasdualito
# Processing Record 39 of Set 11 | falmouth
# Processing Record 40 of Set 11 | vernon
# Processing Record 41 of Set 11 | zarakes
# City not found. Skipping...
# Processing Record 42 of Set 11 | podporozhye
# Processing Record 43 of Set 11 | ngama
# Processing Record 44 of Set 11 | pemangkat
# Processing Record 45 of Set 11 | buenos aires
# Processing Record 46 of Set 11 | grand gaube
# Processing Record 47 of Set 11 | lamu
# Processing Record 48 of Set 11 | karratha
# Processing Record 49 of Set 11 | holme
# Processing Record 50 of Set 11 | riberalta
# Processing Record 1 of Set 12 | tevriz
# Processing Record 2 of Set 12 | palana
# Processing Record 3 of Set 12 | pesochenskiy
# Processing Record 4 of Set 12 | andevoranto
# City not found. Skipping...
# Processing Record 5 of Set 12 | teseney
# Processing Record 6 of Set 12 | sochi
# Processing Record 7 of Set 12 | stornoway
# Processing Record 8 of Set 12 | port blair
# Processing Record 9 of Set 12 | dien bien
# City not found. Skipping...
# Processing Record 10 of Set 12 | taoudenni
# Processing Record 11 of Set 12 | portland
# Processing Record 12 of Set 12 | hualmay
# Processing Record 13 of Set 12 | las vegas
# Processing Record 14 of Set 12 | morgan city
# Processing Record 15 of Set 12 | makakilo city
# Processing Record 16 of Set 12 | aksu
# Processing Record 17 of Set 12 | vestmannaeyjar
# Processing Record 18 of Set 12 | tempoal
# City not found. Skipping...
# Processing Record 19 of Set 12 | santa cruz del norte
# Processing Record 20 of Set 12 | saint-augustin
# Processing Record 21 of Set 12 | khandagayty
# Processing Record 22 of Set 12 | fukue
# Processing Record 23 of Set 12 | romny
# Processing Record 24 of Set 12 | miles city
# Processing Record 25 of Set 12 | saiha
# Processing Record 26 of Set 12 | bah
# Processing Record 27 of Set 12 | visnes
# Processing Record 28 of Set 12 | baringo
# Processing Record 29 of Set 12 | sredec
# City not found. Skipping...
# Processing Record 30 of Set 12 | puro
# Processing Record 31 of Set 12 | ihosy
# Processing Record 32 of Set 12 | enshi
# Processing Record 33 of Set 12 | kenai
# Processing Record 34 of Set 12 | vikindu
# Processing Record 35 of Set 12 | griffith
# Processing Record 36 of Set 12 | badou
# Processing Record 37 of Set 12 | colares
# Processing Record 38 of Set 12 | calama
# Processing Record 39 of Set 12 | gewane
# Processing Record 40 of Set 12 | natal
# Processing Record 41 of Set 12 | salta
# Processing Record 42 of Set 12 | curuguaty
# Processing Record 43 of Set 12 | ixtapa
# Processing Record 44 of Set 12 | mirnyy
# Processing Record 45 of Set 12 | san lawrenz
# Processing Record 46 of Set 12 | azul
# Processing Record 47 of Set 12 | sibolga
# Processing Record 48 of Set 12 | general roca
# Processing Record 49 of Set 12 | fasa
# Processing Record 50 of Set 12 | kapuskasing
# Processing Record 1 of Set 13 | balkanabat
# Processing Record 2 of Set 13 | ayagoz
# Processing Record 3 of Set 13 | tahoua
# Processing Record 4 of Set 13 | waw
# Processing Record 5 of Set 13 | launceston
# Processing Record 6 of Set 13 | santiago
# Processing Record 7 of Set 13 | lingao
# Processing Record 8 of Set 13 | yining
# Processing Record 9 of Set 13 | novaya zaimka
# Processing Record 10 of Set 13 | bacalar
# Processing Record 11 of Set 13 | dzhusaly
# City not found. Skipping...
# Processing Record 12 of Set 13 | kingaroy
# Processing Record 13 of Set 13 | atar
# Processing Record 14 of Set 13 | port-cartier
# Processing Record 15 of Set 13 | lieksa
# Processing Record 16 of Set 13 | fez
# Processing Record 17 of Set 13 | estelle
# Processing Record 18 of Set 13 | harper
# Processing Record 19 of Set 13 | barranca
# Processing Record 20 of Set 13 | luoyang
# Processing Record 21 of Set 13 | berdigestyakh
# Processing Record 22 of Set 13 | batagay-alyta
# Processing Record 23 of Set 13 | warrnambool
# Processing Record 24 of Set 13 | yichun
# Processing Record 25 of Set 13 | laramie
# Processing Record 26 of Set 13 | price
# Processing Record 27 of Set 13 | banjar
# Processing Record 28 of Set 13 | umm lajj
# Processing Record 29 of Set 13 | coihaique
# Processing Record 30 of Set 13 | vaitape
# Processing Record 31 of Set 13 | melbourne
# Processing Record 32 of Set 13 | yashkul
# Processing Record 33 of Set 13 | afonso claudio
# Processing Record 34 of Set 13 | newport
# Processing Record 35 of Set 13 | los llanos de aridane
# Processing Record 36 of Set 13 | naftalan
# Processing Record 37 of Set 13 | mareeba
# Processing Record 38 of Set 13 | kropotkin
# Processing Record 39 of Set 13 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 40 of Set 13 | pestovo
# Processing Record 41 of Set 13 | jardim
# Processing Record 42 of Set 13 | stoyba
# City not found. Skipping...
# Processing Record 43 of Set 13 | bloemfontein
# Processing Record 44 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 45 of Set 13 | kununurra
# Processing Record 46 of Set 13 | shitanjing
# Processing Record 47 of Set 13 | eyl
# Processing Record 48 of Set 13 | sicamous
# Processing Record 49 of Set 13 | port hawkesbury
# Processing Record 50 of Set 13 | umtata
# Processing Record 1 of Set 14 | bacolod
# Processing Record 2 of Set 14 | ca mau
# Processing Record 3 of Set 14 | morristown
# Processing Record 4 of Set 14 | palkaka
# City not found. Skipping...
# Processing Record 5 of Set 14 | tilichiki
# Processing Record 6 of Set 14 | vestmanna
# Processing Record 7 of Set 14 | dumas
# Processing Record 8 of Set 14 | gornyy
# Processing Record 9 of Set 14 | brownsville
# Processing Record 10 of Set 14 | cabra
# Processing Record 11 of Set 14 | ialibu
# Processing Record 12 of Set 14 | port-gentil
# Processing Record 13 of Set 14 | sri aman
# Processing Record 14 of Set 14 | galgani
# City not found. Skipping...
# Processing Record 15 of Set 14 | yinchuan
# Processing Record 16 of Set 14 | vangaindrano
# Processing Record 17 of Set 14 | kita
# Processing Record 18 of Set 14 | jujuy
# City not found. Skipping...
# Processing Record 19 of Set 14 | gardan diwal
# City not found. Skipping...
# Processing Record 20 of Set 14 | volodarskiy
# Processing Record 21 of Set 14 | sergeyevka
# Processing Record 22 of Set 14 | myski
# Processing Record 23 of Set 14 | terre haute
# Processing Record 24 of Set 14 | meyungs
# City not found. Skipping...
# Processing Record 25 of Set 14 | inhambane
# Processing Record 26 of Set 14 | rorvik
# Processing Record 27 of Set 14 | kloulklubed
# Processing Record 28 of Set 14 | ilo
# Processing Record 29 of Set 14 | waipawa
# Processing Record 30 of Set 14 | shelburne
# Processing Record 31 of Set 14 | miragoane
# Processing Record 32 of Set 14 | funchal
# Processing Record 33 of Set 14 | rio grande
# Processing Record 34 of Set 14 | catalao
# Processing Record 35 of Set 14 | ubrique
# Processing Record 36 of Set 14 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 37 of Set 14 | rundu
# Processing Record 38 of Set 14 | payo
# Processing Record 39 of Set 14 | kanash
# Processing Record 40 of Set 14 | lolua
# City not found. Skipping...
# Processing Record 41 of Set 14 | the valley
# Processing Record 42 of Set 14 | barra
# Processing Record 43 of Set 14 | siljan
# Processing Record 44 of Set 14 | concordia
# Processing Record 45 of Set 14 | brockton
# Processing Record 46 of Set 14 | atambua
# Processing Record 47 of Set 14 | caluquembe
# Processing Record 48 of Set 14 | sangar
# Processing Record 49 of Set 14 | malacky
# Processing Record 50 of Set 14 | araouane
# Processing Record 1 of Set 15 | arman
# Processing Record 2 of Set 15 | jiayuguan
# Processing Record 3 of Set 15 | kongolo
# Processing Record 4 of Set 15 | sao raimundo das mangabeiras
# Processing Record 5 of Set 15 | satitoa
# City not found. Skipping...
# Processing Record 6 of Set 15 | tawang
# Processing Record 7 of Set 15 | tanete
# Processing Record 8 of Set 15 | louga
# Processing Record 9 of Set 15 | gol
# Processing Record 10 of Set 15 | vezirkopru
# Processing Record 11 of Set 15 | neiafu
# Processing Record 12 of Set 15 | poli
# Processing Record 13 of Set 15 | sumbawa
# City not found. Skipping...
# Processing Record 14 of Set 15 | hay river
# Processing Record 15 of Set 15 | payakumbuh
# Processing Record 16 of Set 15 | skagastrond
# City not found. Skipping...
# Processing Record 17 of Set 15 | liaozhong
# Processing Record 18 of Set 15 | hamilton
# Processing Record 19 of Set 15 | zhezkazgan
# Processing Record 20 of Set 15 | yilan
# Processing Record 21 of Set 15 | colac
# Processing Record 22 of Set 15 | wajima
# Processing Record 23 of Set 15 | aljezur
# Processing Record 24 of Set 15 | kumluca
# Processing Record 25 of Set 15 | bandarbeyla
# Processing Record 26 of Set 15 | redcliffe
# Processing Record 27 of Set 15 | russell
# Processing Record 28 of Set 15 | kasongo-lunda
# Processing Record 29 of Set 15 | pochutla
# Processing Record 30 of Set 15 | ouro preto
# Processing Record 31 of Set 15 | cabo rojo
# Processing Record 32 of Set 15 | hollabrunn
# Processing Record 33 of Set 15 | verkhoyansk
# Processing Record 34 of Set 15 | barawe
# City not found. Skipping...
# Processing Record 35 of Set 15 | belaya gora
# Processing Record 36 of Set 15 | maku
# Processing Record 37 of Set 15 | zagare
# Processing Record 38 of Set 15 | maldonado
# Processing Record 39 of Set 15 | moree
# Processing Record 40 of Set 15 | singaraja
# Processing Record 41 of Set 15 | sao joao da barra
# Processing Record 42 of Set 15 | buta
# Processing Record 43 of Set 15 | boa vista
# Processing Record 44 of Set 15 | borger
# Processing Record 45 of Set 15 | montepuez
# Processing Record 46 of Set 15 | shingu
# Processing Record 47 of Set 15 | verkhnevilyuysk
# Processing Record 48 of Set 15 | zapolyarnyy
# Processing Record 49 of Set 15 | niquero
# Processing Record 50 of Set 15 | chagda
# City not found. Skipping...
# Processing Record 1 of Set 16 | chuy
# Processing Record 2 of Set 16 | odweyne
# Processing Record 3 of Set 16 | belyy yar
# Processing Record 4 of Set 16 | aras
# Processing Record 5 of Set 16 | jiddah
# City not found. Skipping...
# Processing Record 6 of Set 16 | yozgat
# Processing Record 7 of Set 16 | parainen
# Processing Record 8 of Set 16 | tiarei
# Processing Record 9 of Set 16 | narasannapeta
# Processing Record 10 of Set 16 | omboue
# Processing Record 11 of Set 16 | solwezi
# Processing Record 12 of Set 16 | nizwa
# Processing Record 13 of Set 16 | zeya
# Processing Record 14 of Set 16 | lata
# Processing Record 15 of Set 16 | komsomolskiy
# -----------------------------
# Data Retrieval Complete
# -----------------------------
# 696 city records were retrived

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  San Patricio  28.0170  -97.5169     80.85        90          56
# 1        Broome  42.2506  -75.8330     51.17        82          94
# 2         Hella  67.2000   14.4333     43.88        81          40
# 3  Ponta Do Sol  32.6667  -17.1000     65.03        77          20
# 4       Talnakh  69.4865   88.3972     27.86        71         100
# 5     Hithadhoo  -0.6000   73.0833     81.84        79         100
# 6  Beringovskiy  63.0500  179.3167     32.95        96         100
# 7   Buloh Kasap   2.5536  102.7640     84.11        68          72
# 8        Hirara  24.8000  125.2833     88.07        79          75
# 9       Bubaque  11.2833  -15.8333     77.56        79          14
#
#    Wind Speed Country Current Description
# 0       13.65      US       broken clouds
# 1        1.01      US     overcast clouds
# 2       12.66      NO    scattered clouds
# 3        3.20      PT          few clouds
# 4        1.95      RU     overcast clouds
# 5       18.99      MV     overcast clouds
# 6        6.17      RU     overcast clouds
# 7        2.89      MY       broken clouds
# 8       23.02      JP       broken clouds
# 9        8.57      GW          few clouds

# %%
#reorder he dataframe columns
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]

# %%
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  San Patricio      US  28.0170  -97.5169     80.85        90          56
# 1        Broome      US  42.2506  -75.8330     51.17        82          94
# 2         Hella      NO  67.2000   14.4333     43.88        81          40
# 3  Ponta Do Sol      PT  32.6667  -17.1000     65.03        77          20
# 4       Talnakh      RU  69.4865   88.3972     27.86        71         100
# 5     Hithadhoo      MV  -0.6000   73.0833     81.84        79         100
# 6  Beringovskiy      RU  63.0500  179.3167     32.95        96         100
# 7   Buloh Kasap      MY   2.5536  102.7640     84.11        68          72
# 8        Hirara      JP  24.8000  125.2833     88.07        79          75
# 9       Bubaque      GW  11.2833  -15.8333     77.56        79          14
#
#    Wind Speed Current Description
# 0       13.65       broken clouds
# 1        1.01     overcast clouds
# 2       12.66    scattered clouds
# 3        3.20          few clouds
# 4        1.95     overcast clouds
# 5       18.99     overcast clouds
# 6        6.17     overcast clouds
# 7        2.89       broken clouds
# 8       23.02       broken clouds
# 9        8.57          few clouds

# %%
# Create the output file (CSV).
output_data_file = "../Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
